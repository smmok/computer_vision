# %%
run -i ch8_generate_dataset.py

# %%
run -i ch8_knn_points
# Out:
# 1.0

# %%
run -i ch8_dsift
# Out:
# processed tmp.pgm to empire.sift
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/dev/computer_vision/PCV/examples/ch8_dsift.py in <module>
#      11
#      12 dsift.process_image_dsift('../data/empire.jpg', 'empire.sift', 90, 40, True)
# ---> 13 l,d = sift.read_features_from_file('empire.sift')
#      14
#      15 im = array(Image.open('../data/empire.jpg'))
#
# ~/anaconda3/envs/PCV/lib/python3.7/site-packages/PCV/localdescriptors/sift.py in read_features_from_file(filename)
#      23     """ Read feature properties and return in matrix form. """
#      24
# ---> 25     f = loadtxt(filename)
#      26     return f[:,:4],f[:,4:] # feature locations, descriptors
#      27
#
# ~/anaconda3/envs/PCV/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
# ...
